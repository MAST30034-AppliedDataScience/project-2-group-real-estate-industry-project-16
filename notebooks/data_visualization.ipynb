# %%
import pandas as pd

# Read the CSV file into a DataFrame
recent_rent = pd.read_csv('../data/curated/2024_rent.csv')
history_rent = pd.read_csv('../data/curated/history_rent.csv')

# %%
history_rent = history_rent.drop(columns=['Zone'])

# %%
# Concatenate the two DataFrames along rows (axis=0)
rent = pd.concat([history_rent, recent_rent], ignore_index=True)

# Display the combined DataFrame
rent
# Out:
#                                     Location  Year Month Count  Median  Bed  \
# 0      Albert Park-Middle Park-West St Kilda  2000   Dec   369     175    1
# 1      Albert Park-Middle Park-West St Kilda  2000   Jun   347     165    1
# 2      Albert Park-Middle Park-West St Kilda  2000   Mar   352     165    1
# 3      Albert Park-Middle Park-West St Kilda  2000   Sep   378     170    1
# 4      Albert Park-Middle Park-West St Kilda  2001   Dec   423     190    1
# ...                                      ...   ...   ...   ...     ...  ...
# 88813                             Yarraville  2024   Aug     1   700.0    2
# 88814                             Yarraville  2024   Aug     1   780.0    3
# 88815                             Yarraville  2024   Aug     2   950.0    4
# 88816                             Yarraville  2024   Aug     1  1400.0    5
# 88817                                 Yinnar  2024   Aug     1   500.0    4
#
#        Apartment
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
# ...          ...
# 88813          0
# 88814          0
# 88815          0
# 88816          0
# 88817          0
#
# [88818 rows x 7 columns]
