# %%
import json
import pandas as pd

# %%
with open('../data/raw/example.json', 'r') as file:
    data = json.load(file)

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#           https://www.domain.com.au/911-2-joseph-road-footscray-vic-3011-17190827  \
# name                   911/2 Joseph Road, Footscray VIC 3011
# cost_text                                      $600 per week
# rooms                                      [2 Beds, 2 Baths]
# parking                                          [1 Parking]
# desc                                                  Kim Te
#
#           https://www.domain.com.au/20-tibrockney-street-highett-vic-3190-17190750  \
# name                  20 Tibrockney Street, Highett VIC 3190
# cost_text                                            $650.00
# rooms                                      [3 Beds, 2 Baths]
# parking                                          [1 Parking]
# desc                                             Alvin Vitor
#
#           https://www.domain.com.au/13-carrington-street-hampton-east-vic-3188-17190718  \
# name             13 Carrington Street, Hampton East VIC 3188
# ...
