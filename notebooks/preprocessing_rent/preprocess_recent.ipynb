# %%
import pandas as pd
import re
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Preprocessing current data for prediction

# %%
df = pd.read_csv('../../data/raw/location_rent.csv')

# %%
# Create a condition to check if the name has a flat number (pattern "number/")

df['Apartment'] = df['name'].apply(lambda x: 1 if '/' in x else 0)
df.head(5)
# Out:
#                                               name  Bed  weekly_rent  \
# 0  1208/50 Albert Street, South Melbourne VIC 3205    1        520.0
# 1            64 Mills Street, Albert Park VIC 3206    3       1495.0
# 2               11 Barnato St, Weir Views VIC 3338    4        460.0
# 3  1104/70 Southbank Boulevard, Southbank VIC 3006    1        420.0
# 4             167 Charman Road, Beaumaris VIC 3193    4        950.0
#
#    Apartment
# 0          1
# 1          0
# 2          0
# 3          1
# 4          0

# %%
# Function to extract the suburb and postcode from the 'name' column
def extract_location_postcode(address):
    # Regex pattern to capture the suburb name and postcode (VIC followed by 4 digits)
    pattern = r'(?P<suburb>[A-Za-z\s]+) VIC (?P<postcode>\d{4})'
    match = re.search(pattern, address)
    if match:
        return match.group('suburb').strip(), match.group('postcode')
    return None, None

# Apply the function to each row in the 'name' column
df['Location'], df['Postcode'] = zip(*df['name'].apply(extract_location_postcode))

# delete name column
df = df.drop(columns=['name'])

# Display the modified dataframe
df.head()
# Out:
#    Bed  weekly_rent  Apartment         Location Postcode
# 0    1        520.0          1  South Melbourne     3205
# 1    3       1495.0          0      Albert Park     3206
# 2    4        460.0          0       Weir Views     3338
# 3    1        420.0          1        Southbank     3006
# 4    4        950.0          0        Beaumaris     3193

# %%
'''
Outliers detecting and cleaning
'''

# Filter based on your conditions:
# Apartments (Type 1) with Bed <= 3
# Houses (Type 0) with 2 <= Bed <= 4
df_filtered = df[((df['Apartment'] == 1) & (df['Bed'] <= 3)) | 
                 ((df['Apartment'] == 0) & (df['Bed'].between(2, 4)))]

# Calculate the data volume
N = len(df_filtered['weekly_rent'].dropna())

# Calculate the quartiles and IQR
Q1 = np.percentile(df_filtered['weekly_rent'].dropna(), 25)
Q3 = np.percentile(df_filtered['weekly_rent'].dropna(), 75)
IQR = Q3 - Q1

# Apply the corresponding outlier determination rule based on the number of records N
if N <= 100:
    factor = 1.5
else:
    factor = np.sqrt(np.log(N)) - 0.5

# Calculate the upper and lower bounds for outliers
lower_bound = Q1 - factor * IQR
upper_bound = Q3 + factor * IQR

# Plot a boxplot of the 'weekly_rent' column with outlier bounds
plt.figure(figsize=(10, 6))
plt.boxplot(df_filtered['weekly_rent'].dropna(), vert=False, patch_artist=True, 
            boxprops=dict(facecolor='lightgreen', color='black'),
            medianprops=dict(color='red'),
            whiskerprops=dict(color='black'),
            capprops=dict(color='black'),
            flierprops=dict(marker='o', color='red', alpha=0.5))

# Set the x-axis limit to the calculated upper bound based on the new IQR rule
plt.xlim(0, upper_bound)
plt.title('Boxplot of Weekly Rent with Custom IQR Rule Applied')
plt.xlabel('Weekly Rent')
plt.grid(True)
plt.show()

# Remove outliers based on the calculated bounds
df_cleaned = df_filtered[(df_filtered['weekly_rent'] >= 20) & 
                         (df_filtered['weekly_rent'] <= upper_bound)]


df_cleaned.head()
# Out:
#    Bed  weekly_rent  Apartment         Location Postcode
# 0    1        520.0          1  South Melbourne     3205
# 2    4        460.0          0       Weir Views     3338
# 3    1        420.0          1        Southbank     3006
# 4    4        950.0          0        Beaumaris     3193
# 5    3       1200.0          1           Elwood     3184

# %%
df = df_cleaned.groupby(['Postcode', 'Bed', 'Apartment']).agg(
    Count=('weekly_rent', 'size'),    # Count number of rows
    Median=('weekly_rent', 'median')  # Median of weekly_rent
).reset_index()

# %%
# Manually add 'Year' and 'Month' columns with a fixed value (2023 and August)

df['Year'] = 2024
df['Month'] = 'Aug'

# %%
df.head()
# Out:
#   Postcode  Bed  Apartment  Count  Median  Year Month
# 0     3000    1          1     22   485.0  2024   Aug
# 1     3000    2          1     25   600.0  2024   Aug
# 2     3000    3          1      3  1175.0  2024   Aug
# 3     3002    1          1      6   475.0  2024   Aug
# 4     3002    2          1      5   660.0  2024   Aug

# %%
# Define the path for the "curated data" folder
file_path = '../../data/landing/2024_rent.csv'

# Save the DataFrame to the specified path in CSV format
df.to_csv(file_path, index=False)

# %% [markdown]
# ## Preprocessing current data for visualization

# %%
current = pd.read_csv('../../data/landing/nearest_distance.csv')

# %%
# Create a condition to check if the name has a flat number (pattern "number/")

current['Apartment'] = current['name'].apply(lambda x: 1 if '/' in x else 0)
current.head(3)
# Out:
#                                               name  Bed  weekly_rent  \
# 0  1208/50 Albert Street, South Melbourne VIC 3205    1        520.0
# 1            64 Mills Street, Albert Park VIC 3206    3       1495.0
# 2               11 Barnato St, Weir Views VIC 3338    4        460.0
#
#     latitude   longitude                                       geometry  \
# 0 -37.834344  144.955904  POINT (2496118.3794249045 2407409.7981049973)
# 1 -37.846426  144.958009    POINT (2496304.26476775 2406068.9190204293)
# 2 -37.718775  144.554187   POINT (2460697.114285021 2420145.1730066407)
#
#                                    nearest_tram_stop  \
# 0  127-South Melbourne Station/Light Rail (South ...
# 1           135-Richardson St/Mills St (Middle Park)
# 2      49-Central Park Ave/Cordite Ave (Maribyrnong)
#
#    nearest_tram_stop_distance_km  \
# 0                       0.136816
# 1                       0.090635
# 2                      29.072242
#
#                                   nearest_train_stop  \
# 0  67-Camberwell Girls Grammar/Burke Rd (Hawthorn...
# 1        49-Buchanan Ave/Doncaster Rd (Balwyn North)
# 2           46-Orrong Rd/Glenhuntly Rd (Elsternwick)
#
#    nearest_train_stop_distance_km                            nearest_bus_stop  \
# 0                        1.863573      Ferrars St/Dorcas St (South Melbourne)
# 1                        2.824165  Middle Park PS/Richardson St (Middle Park)
# 2                       17.817118             Hume Ave/Rees Rd (Melton South)
#
#    nearest_bus_stop_distance_km                            nearest_school  \
# 0                      0.034790  Galilee Regional Catholic Primary School
# 1                      0.095911                Middle Park Primary School
# 2                      1.047037                           Al Iman College
#
#    nearest_school_distance_km  Apartment
# 0                    0.223329          1
# 1                    0.158652          0
# 2                    1.632357          0

# %%
# Apartments (Apartment=1) with Bed <= 3
# Houses (Apartment=0) with 2 <= Bed <= 4
current_filtered = current[((current['Apartment'] == 1) & (current['Bed'] <= 3)) | 
                           ((current['Apartment'] == 0) & (current['Bed'].between(2, 4)))]

# Calculate the data volume
N = len(current_filtered['weekly_rent'].dropna())
print(N)

# Calculate the quartiles and IQR
Q1 = np.percentile(current_filtered['weekly_rent'].dropna(), 25)
Q3 = np.percentile(current_filtered['weekly_rent'].dropna(), 75)
IQR = Q3 - Q1

# Apply the corresponding outlier determination rule based on the number of records N
if N <= 100:
    factor = 1.5
else:
    factor = np.sqrt(np.log(N) - 0.5)

# Calculate the upper and lower bounds for outliers
lower_bound = Q1 - factor * IQR
upper_bound = Q3 + factor * IQR

# Plot a boxplot of the 'weekly_rent' column with outlier bounds
plt.figure(figsize=(10, 6))
plt.boxplot(current_filtered['weekly_rent'].dropna(), vert=False, patch_artist=True, 
            boxprops=dict(facecolor='lightgreen', color='black'),
            medianprops=dict(color='red'),
            whiskerprops=dict(color='black'),
            capprops=dict(color='black'),
            flierprops=dict(marker='o', color='red', alpha=0.5))

# Set the x-axis limit to the calculated upper bound based on the new IQR rule
plt.xlim(0, upper_bound)
plt.title('Boxplot of Weekly Rent with Custom IQR Rule Applied')
plt.xlabel('Weekly Rent')
plt.grid(True)
plt.show()

# Remove outliers based on the calculated bounds
current = current_filtered[(current_filtered['weekly_rent'] >= 20) & 
                                   (current_filtered['weekly_rent'] <= upper_bound)]


current.head(3)
# Out:
# 2207
#                                               name  Bed  weekly_rent  \
# 0  1208/50 Albert Street, South Melbourne VIC 3205    1        520.0
# 2               11 Barnato St, Weir Views VIC 3338    4        460.0
# 3  1104/70 Southbank Boulevard, Southbank VIC 3006    1        420.0
#
#     latitude   longitude                                       geometry  \
# 0 -37.834344  144.955904  POINT (2496118.3794249045 2407409.7981049973)
# 2 -37.718775  144.554187   POINT (2460697.114285021 2420145.1730066407)
# 3 -37.823158  144.963953    POINT (2496826.48889558 2408651.6629420286)
#
#                                    nearest_tram_stop  \
# 0  127-South Melbourne Station/Light Rail (South ...
# 2      49-Central Park Ave/Cordite Ave (Maribyrnong)
# 3  115-Casino/Southbank/Queens Bridge St (Southbank)
#
#    nearest_tram_stop_distance_km  \
# 0                       0.136816
# 2                      29.072242
# 3                       0.266535
#
#                                   nearest_train_stop  \
# 0  67-Camberwell Girls Grammar/Burke Rd (Hawthorn...
# 2           46-Orrong Rd/Glenhuntly Rd (Elsternwick)
# 3             41-Cantala Ave/Dandenong Rd (Armadale)
#
#    nearest_train_stop_distance_km                        nearest_bus_stop  \
# 0                        1.863573  Ferrars St/Dorcas St (South Melbourne)
# 2                       17.817118         Hume Ave/Rees Rd (Melton South)
# 3                        0.600295       City Rd/Southbank Bvd (Southbank)
#
#    nearest_bus_stop_distance_km  \
# 0                      0.034790
# 2                      1.047037
# 3                      0.061561
#
#                                    nearest_school  nearest_school_distance_km  \
# 0        Galilee Regional Catholic Primary School                    0.223329
# 2                                 Al Iman College                    1.632357
# 3  Victorian College Of The Arts Secondary School                    0.567526
#
#    Apartment
# 0          1
# 2          0
# 3          1

# %%
# Apply the function to each row in the 'name' column
current['Location'], current['Postcode'] = zip(*current['name'].apply(extract_location_postcode))

# delete name column
current = current.drop(columns=['name'])

# Display the modified dataframe
current.head(3)
# Out:
# /var/folders/k7/_mb_sxqs3kq79v5w1cmsbshm0000gn/T/ipykernel_85439/923852723.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   current['Location'], current['Postcode'] = zip(*current['name'].apply(extract_location_postcode))
# /var/folders/k7/_mb_sxqs3kq79v5w1cmsbshm0000gn/T/ipykernel_85439/923852723.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   current['Location'], current['Postcode'] = zip(*current['name'].apply(extract_location_postcode))
#    Bed  weekly_rent   latitude   longitude  \
# 0    1        520.0 -37.834344  144.955904
# 2    4        460.0 -37.718775  144.554187
# 3    1        420.0 -37.823158  144.963953
#
#                                         geometry  \
# 0  POINT (2496118.3794249045 2407409.7981049973)
# 2   POINT (2460697.114285021 2420145.1730066407)
# 3    POINT (2496826.48889558 2408651.6629420286)
#
#                                    nearest_tram_stop  \
# 0  127-South Melbourne Station/Light Rail (South ...
# 2      49-Central Park Ave/Cordite Ave (Maribyrnong)
# 3  115-Casino/Southbank/Queens Bridge St (Southbank)
#
#    nearest_tram_stop_distance_km  \
# 0                       0.136816
# 2                      29.072242
# 3                       0.266535
#
#                                   nearest_train_stop  \
# 0  67-Camberwell Girls Grammar/Burke Rd (Hawthorn...
# 2           46-Orrong Rd/Glenhuntly Rd (Elsternwick)
# 3             41-Cantala Ave/Dandenong Rd (Armadale)
#
#    nearest_train_stop_distance_km                        nearest_bus_stop  \
# 0                        1.863573  Ferrars St/Dorcas St (South Melbourne)
# 2                       17.817118         Hume Ave/Rees Rd (Melton South)
# 3                        0.600295       City Rd/Southbank Bvd (Southbank)
#
#    nearest_bus_stop_distance_km  \
# 0                      0.034790
# 2                      1.047037
# 3                      0.061561
#
#                                    nearest_school  nearest_school_distance_km  \
# 0        Galilee Regional Catholic Primary School                    0.223329
# 2                                 Al Iman College                    1.632357
# 3  Victorian College Of The Arts Secondary School                    0.567526
#
#    Apartment         Location Postcode
# 0          1  South Melbourne     3205
# 2          0       Weir Views     3338
# 3          1        Southbank     3006

# %%
current = current.drop(columns=['latitude','longitude','geometry','nearest_tram_stop','nearest_train_stop','nearest_bus_stop','nearest_school','Location'])
current.head(3)
# Out:
#    Bed  weekly_rent  nearest_tram_stop_distance_km  \
# 0    1        520.0                       0.136816
# 2    4        460.0                      29.072242
# 3    1        420.0                       0.266535
#
#    nearest_train_stop_distance_km  nearest_bus_stop_distance_km  \
# 0                        1.863573                      0.034790
# 2                       17.817118                      1.047037
# 3                        0.600295                      0.061561
#
#    nearest_school_distance_km  Apartment Postcode
# 0                    0.223329          1     3205
# 2                    1.632357          0     3338
# 3                    0.567526          1     3006

# %%
# Define the path for the "curated data" folder
file_path = '../../data/landing/2024_rent_loc.csv'

# Save the DataFrame to the specified path in CSV format
current.to_csv(file_path, index=False)
